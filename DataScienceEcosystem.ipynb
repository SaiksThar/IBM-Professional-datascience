# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notbook represents the summerization of the tools that commonly use in Data Science fields.

# %% [markdown]
# __Objectives:__
# - popular data science languages
# - popular data science labaries
# - markdown table
# - H3 arithemetic
# - arithmetic in coding
# - python program

# %% [markdown]
# some of the popular languages that are used in Data Science field are
#
#     1. Python
#     2. R
#     3. SQL
#     4. Julia
#     5. Scala

# %% [markdown]
# some of the popular Data Science libaries are
#
#     1. Panda
#     2. Keras
#     3. Tensorflow
#     4. Numpy
#     5. Scikit-learn
#     6. Matplotlib

# %% [markdown]
#   | Data Science Tools |  Description |
#   | :---------------- | :-----------|
#   | Jupyter Notebook | Open-source web-based environment that supports variety of languages and document styles |
#   | RStudio | open-source IDE for R language includes range of tools for data analysis |
#   |Spyder | Open-source IDE  for scientific Python for data analysis, debugging |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(4*3)+20
# Out:
# 32

# %%
min = 200
def minToHr(n):
    hr = n//60
    m = n%60
    return f" {hr} hour and {m} min"

minToHr(min)
# Out:
# ' 3 hour and 20 min'

# %% [markdown]
# ## Author
# Sai Thar
