# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Sai Thar__ <br>
#  I would like to be a successful data scientist.

# %% [markdown]
# _I am interested in data science because I like to work with data and also it is a growing job across the world._

# %% [markdown]
# ### The following code Ask user any integer > 0 and it will distinguish wither the input is odd or even.

# %%
n = int(input('Please inter any integer'))
def odd_or_even(n):
    if n%2== 0:
        return "even"
    else:
        return "odd"

print(odd_or_even(n))
# Out:
# Please inter any integer20
# even

# %% [markdown]
#  ***
#  - bullet 1
#  - bullet 2
#  - bullet 3
#  ***
# 1. num one
# 2. num two
# 3. num three
#  ***
#  <div class="alert alert-block alert-info">
# <b>Tip:</b>
#     testing blue box:
# </div>
